# %%
import numpy as np
import pandas as pd

#read pickle file
df = pd.read_pickle('../../data/tweets.pkl')

# %%
df
# Out:
#                 created_at                      hashtags  favorite_count  \
# 0      2011-03-06 04:29:30                  [MileyonSNL]               0
# 1      2011-03-06 04:29:22                  [MileyOnSNL]               0
# 2      2011-03-06 04:29:21                  [MileyOnSNL]               2
# 3      2011-03-06 04:29:19                  [MileyOnSNL]               0
# 4      2011-03-06 04:29:15                  [MileyOnSNL]               0
# 5      2011-03-06 04:29:15                  [MileyOnSNL]               0
# 6      2011-03-06 04:29:14                  [MileyonSNL]               0
# 7      2011-03-06 04:29:10                  [mileyonSNL]               0
# 8      2011-03-06 04:29:10                  [MileyOnSNL]               0
# 9      2011-03-06 04:29:01                  [MileyOnSNL]               0
# 10     2011-03-06 04:29:00                  [MileyOnSNL]               0
# 11     2011-03-06 04:28:59                  [MileyOnSNL]               0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325916 entries, 0 to 325915
# Data columns (total 17 columns):
# created_at                 325916 non-null datetime64[ns]
# hashtags                   325916 non-null object
# favorite_count             325916 non-null int64
# id                         325916 non-null int64
# user_id                    325916 non-null int64
# user_followers_count       325916 non-null int64
# retweet_count              325916 non-null int64
# in_reply_to_status_id      22543 non-null float64
# in_reply_to_user_id        32537 non-null float64
# source                     325916 non-null object
# text                       325916 non-null object
# original_tweet_id          60016 non-null float64
# original_tweet_text        60016 non-null object
# original_tweet_hashtags    21874 non-null object
# trending_date              325916 non-null int64
# topic                      325916 non-null object
# ...
